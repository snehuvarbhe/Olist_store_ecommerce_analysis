# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = r'D:\git_projects\retail_data_analysis\Olist_store_ecommerce_analysis\dataset\data_final.csv'
data = pd.read_csv(file_path)

# Display dataset overview
print("Dataset Overview:")
data.head(3)
# Out:
# Dataset Overview:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered         02-10-2017 10:56  02-10-2017 11:07
# 1    delivered         02-10-2017 10:56  02-10-2017 11:07
# 2    delivered         02-10-2017 10:56  02-10-2017 11:07
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0             04-10-2017 19:55              10-10-2017 21:25
# 1             04-10-2017 19:55              10-10-2017 21:25
# 2             04-10-2017 19:55              10-10-2017 21:25
#
#   order_estimated_delivery_date  order_confirm_days  payment_sequential  ...  \
# 0                    18-10-2017            0.007431                 1.0  ...
# 1                    18-10-2017            0.007431                 3.0  ...
# 2                    18-10-2017            0.007431                 2.0  ...
#
#   review_creation_date  review_answer_timestamp  product_name_length  \
# 0           11-10-2017         12-10-2017 03:43                 40.0
# 1           11-10-2017         12-10-2017 03:43                 40.0
# 2           11-10-2017         12-10-2017 03:43                 40.0
#
#   product_description_length  product_photos_qty product_weight_g  \
# 0                      268.0                 4.0            500.0
# 1                      268.0                 4.0            500.0
# 2                      268.0                 4.0            500.0
#
#   product_length_cm  product_height_cm  product_width_cm  \
# 0              19.0                8.0              13.0
# 1              19.0                8.0              13.0
# 2              19.0                8.0              13.0
#
#    product_category_name_english
# 0                     housewares
# 1                     housewares
# 2                     housewares
#
# [3 rows x 40 columns]

# %%
# Display dataset information
print("\nDataset Information:")
data.info()

# Handling Missing Values
print("\nMissing Values Count:")
print(data.isnull().sum())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115344 entries, 0 to 115343
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115344 non-null  object
#  1   customer_id                    115344 non-null  object
#  2   order_status                   115344 non-null  object
#  3   order_purchase_timestamp       115344 non-null  object
#  4   order_approved_at              115344 non-null  object
#  5   order_delivered_carrier_date   115344 non-null  object
#  6   order_delivered_customer_date  115344 non-null  object
#  7   order_estimated_delivery_date  115344 non-null  object
#  8   order_confirm_days             115344 non-null  float64
#  9   payment_sequential             115341 non-null  float64
#  10  payment_type                   115341 non-null  object
#  11  payment_installments           115341 non-null  float64
#  12  payment_value                  115341 non-null  float64
#  13  customer_unique_id             115344 non-null  object
#  14  customer_zip_code              115344 non-null  int64
#  15  customer_city                  115344 non-null  object
#  16  customer_state                 115344 non-null  object
#  17  customer_lat                   115044 non-null  float64
#  18  customer_lng                   115044 non-null  float64
#  19  order_item_id                  115344 non-null  int64
#  20  product_id                     115344 non-null  object
#  21  seller_id                      115344 non-null  object
#  22  shipping_limit_date            115344 non-null  object
#  23  price                          115344 non-null  float64
#  24  transport_cost                 115344 non-null  float64
#  25  seller_zip_code_prefix         115344 non-null  int64
#  26  seller_city                    115344 non-null  object
#  27  seller_state                   115344 non-null  object
#  28  review_id                      113929 non-null  object
#  29  review_score                   113929 non-null  float64
#  30  review_creation_date           113929 non-null  object
#  31  review_answer_timestamp        113929 non-null  object
#  32  product_name_length            113708 non-null  float64
#  33  product_description_length     113708 non-null  float64
#  34  product_photos_qty             113708 non-null  float64
#  35  product_weight_g               113708 non-null  float64
#  36  product_length_cm              113708 non-null  float64
#  37  product_height_cm              113708 non-null  float64
#  38  product_width_cm               113708 non-null  float64
#  39  product_category_name_english  113685 non-null  object
# dtypes: float64(16), int64(3), object(21)
# memory usage: 35.2+ MB
#
# Missing Values Count:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date        0
# order_delivered_customer_date       0
# order_estimated_delivery_date       0
# order_confirm_days                  0
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# customer_unique_id                  0
# customer_zip_code                   0
# customer_city                       0
# customer_state                      0
# customer_lat                      300
# customer_lng                      300
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# transport_cost                      0
# seller_zip_code_prefix              0
# seller_city                         0
# seller_state                        0
# review_id                        1415
# review_score                     1415
# review_creation_date             1415
# review_answer_timestamp          1415
# product_name_length              1636
# product_description_length       1636
# product_photos_qty               1636
# product_weight_g                 1636
# product_length_cm                1636
# product_height_cm                1636
# product_width_cm                 1636
# product_category_name_english    1659
# dtype: int64
